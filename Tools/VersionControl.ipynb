# %% [markdown]
# # Version Control
# ---
#
# the task of keeping a software system consisting of many versions and configurations well organized.

# %% [markdown]
# **Types**
#
# - Centralized *History is maintained in single centralised location*
#     - Subversion (svn)
#
# - Distributed *Each user has their own copy of history*
#     - Git (git)
#     - Mercurial (hg)

# %% [markdown]
# **Free Hosting**
#
# - Github *[ popular ]*
#     - git
#     - free only for open source projects
# - Gitlab
#     - git
#     - free private reposiitories
# - Bitbucket
#     - git
#     - hg
#     - free private repositories
#     - limited to 5 users

# %% [markdown]
# **Tools**
#
# [ Windows (Git only) ]
#     - TortoiseGit [https://tortoisegit.org/](https://tortoisegit.org/)
#
# [ Windows/MacOSX/Linux (Hg only) ]
#     - TortoiseHg [http://tortoisehg.bitbucket.org/](http://tortoisehg.bitbucket.org/)
#
# [ Windows/MacOSX (Git/Hg) for Github and Bitbucket ]
#     - SourceTree [https://www.sourcetreeapp.com/](https://www.sourcetreeapp.com/)
#
# [ Windows/macOSX (Git) for Github ]
#     - Github for Desktop [https://desktop.github.com/](https://desktop.github.com/)
#
# [ Linux ]
#
#     $ sudo apt-get install git mercurial [ Ubuntu ]
#
#     $ sudo yum install git mercurial [ Redhat/Fedora ]
#
#     $ sudo pacman -S git mercurial [ ArchLinux ]

# %% [markdown]
# ## Git
#
# - Clone a repository
#
#     $ git clone https://github.com/idwaker/pysessions.git
#
# - Working with the git
#
#     $ cd pysession
#
#     *show changes made on files*
#
#     $ git status
#
#
# - Adding new file to git
#
#     *tracking new files / create new file named CHANGELOG*
#
#     $ git add CHANGELOG
#
#
# - Commiting changes
#
#     *commit message is short text that we want to identify this part of history with*
#
#     $ git commit -m "added CHANGELOG"
#
#
# - Listing hostory log
#
#     $ git log
#
# - Remote repository
#
#     $ git remote -v
#         origin	git@github.com:idwaker/pysessions (fetch)
#         origin	git@github.com:idwaker/pysessions (push)
#
#     *origin is alias to remote repository*
#
# - Pulling from remote
#
#     $ git pull origin master
#
#     *master is special branch/lineage on which we are working*
#
# - Pushing our changes to remote
#
#     $ git push origin master

# %% [markdown]
# ## Hg
#
# - Clone a repository
#
#     $ hg clone https://bitbucket.org/idwaker/dotfiles
#
# - Working with the hg
#
#     $ cd pysession
#
#     *show changes made on files*
#
#     $ hg status
#
#
# - Adding new file to hg
#
#     *tracking new files / create new file named CHANGELOG*
#
#     $ hg add CHANGELOG
#
#
# - Commiting changes
#
#     *commit message is short text that we want to identify this part of history with*
#
#     $ hg commit -m "added CHANGELOG"
#
#     $ hg ci -m "added CHANGELOG"
#
#
# - Listing hostory log
#
#     $ hg log
#
#
# - Pulling from remote
#
#     $ hg pull
#
#     *default is special branch/lineage on which we are working*
#
# - Pushing our changes to remote
#
#     $ hg push

# %% [markdown]
# ## Maintaining forks
# ---
#
# Repository forked from https://github.com/idwaker/pysessions.git by user 'student'
#
#     $ git clone https://github.com/student/pysessions.git
#
#     $ cd pysessions
#
#     $ git remote add upstream https://github.com/idwaker/pysessions.git
#
#     $ git remote -v
#         origin    https://github.com/student/pysessions.git (fetch)
#         origin    https://github.com/student/pysessions.git (push)
#         upstream    https://github.com/idwaker/pysessions.git (fetch)
#         upstream    https://github.com/idwaker/pysessions.git (push)
#
#     $ git checkout master
#
#     $ git fetch upstream
#
#     $ git merge upstream/master
#
#     $ git pull origin master
#
#     $ git push origin master
