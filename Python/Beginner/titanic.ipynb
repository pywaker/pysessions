# %%
import pandas as pd

# %%
data = pd.read_excel('/media/mohit/mohit1/githubfile/pysessions/dataset/titanic_train_data.xls')

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
data.head()
# Out:
#    pclass  survived                                            name     sex  \
# 0       1         1                         Bishop, Mr. Dickinson H    male
# 1       3         0                   Somerton, Mr. Francis William    male
# 2       3         0               Andersson, Miss. Sigrid Elisabeth  female
# 3       3         0  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female
# 4       3         0                      Tomlin, Mr. Ernest Portage    male
#
#     age  sibsp  parch      ticket     fare cabin embarked boat  body  \
# 0  25.0      1      0       11967  91.0792   B49        C    7   NaN
# 1  30.0      0      0  A.5. 18509   8.0500   NaN        S  NaN   NaN
# 2  11.0      4      2      347082  31.2750   NaN        S  NaN   NaN
# 3  40.0      1      0        7546   9.4750   NaN        S  NaN   NaN
# 4  30.5      0      0      364499   8.0500   NaN        S  NaN  50.0
#
#              home.dest
# 0         Dowagiac, MI
# 1                  NaN
# ...

# %%
data.count()
# Out:
# pclass       981
# survived     981
# name         981
# sex          981
# age          778
# sibsp        981
# parch        981
# ticket       981
# fare         980
# cabin        219
# embarked     981
# boat         363
# body          93
# home.dest    556
# dtype: int64

# %%
data.groupby("sex")["age"].mean()
# Out:
# sex
# female    28.970218
# male      30.939425
# Name: age, dtype: float64

# %%
avg_age=data.groupby("sex")["age"].mean()

# %%
avg_age.index
avg_age['male']
# Out:
# 30.939425051334702

# %%
a=avg_age['male']
b=avg_age['female']
means = data.groupby('sex').age.mean()
print(means)
# Out:
# sex
# female    28.970218
# male      30.939425
# Name: age, dtype: float64

# %%
data['age'] = data['age'].fillna(means)
data
# Out:
#      pclass  survived                                               name  \
# 0         1         1                            Bishop, Mr. Dickinson H
# 1         3         0                      Somerton, Mr. Francis William
# 2         3         0                  Andersson, Miss. Sigrid Elisabeth
# 3         3         0     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 4         3         0                         Tomlin, Mr. Ernest Portage
# 5         3         0                          Everett, Mr. Thomas James
# 6         3         0                          Rice, Master. George Hugh
# 7         3         0                                 Khalil, Mr. Betros
# 8         2         1           Hold, Mrs. Stephen (Annie Margaret Hill)
# 9         3         0               Hagland, Mr. Konrad Mathias Reiersen
# 10        3         0                   Olsson, Mr. Nils Johan Goransson
# 11        1         0                   Compton, Mr. Alexander Taylor Jr
# ...

# %%
print(data.apply(lambda x: means[x.sex] if pd.isnull(x.age) else x.age,axis=1) )
data["age_refined"]=data.apply(lambda d:avg_age[d['sex']] if pd.isnull(d['age'])else d['age'],axis=1)
data
# Out:
# 0      25.000000
# 1      30.000000
# 2      11.000000
# 3      40.000000
# 4      30.500000
# 5      40.500000
# 6       8.000000
# 7      30.939425
# 8      29.000000
# 9      30.939425
# 10     28.000000
# 11     37.000000
# 12     30.000000
# 13     18.000000
# 14     17.000000
# 15     30.939425
# 16     30.939425
# 17     27.000000
# 18     15.000000
# 19     45.000000
# 20     18.500000
# 21     16.000000
# 22     28.970218
# 23     30.000000
# 24     39.000000
# 25     30.939425
# 26     46.000000
# 27     30.939425
# 28      8.000000
# 29     29.000000
#          ...
# 951    36.000000
# 952    22.000000
# 953    48.000000
# 954     7.000000
# 955    21.000000
# 956    33.000000
# 957    36.000000
# 958    36.000000
# 959    40.000000
# 960    54.000000
# 961    18.000000
# 962    24.000000
# 963    30.939425
# 964    21.000000
# 965    21.000000
# 966    28.970218
# 967    18.000000
# 968    29.000000
# 969    30.000000
# 970    36.000000
# 971    51.000000
# ...

# %%
'''means = data.groupby('sex').age.mean()
for i in data[data.age.isnull()].index:
    data.loc[i, 'age'] = means[data.loc[i].sex]'''
# Out:
# "means = data.groupby('sex').age.mean()\nfor i in data[data.age.isnull()].index:\n    data.loc[i, 'age'] = means[data.loc[i].sex]"

# %%
print('{} age= {}'.format(data.loc[data['age'].idxmax(),'name'],data['age'].max()))

print('{} age= {}'.format(data.loc[data['age'].idxmin(),'name'],data['age'].min()))
# Out:
# Barkworth, Mr. Algernon Henry Wilson age= 80.0
# Dean, Miss. Elizabeth Gladys "Millvina" age= 0.1667

# %%
print(data.groupby("sex")["age"].max())
print(data.groupby("sex")["age"].min())
# Out:
# sex
# female    76.0
# male      80.0
# Name: age, dtype: float64
# sex
# female    0.1667
# male      0.6667
# Name: age, dtype: float64

# %%
print(data[(data['sex']=='male')]["age"].max())

print(data[(data['sex']=='male')]["age"].min())
# Out:
# 80.0
# 0.6667

# %%
print(data[(data['sex']=='female')]["age"].max())

print(data[(data['sex']=='female')]["age"].min())
# Out:
# 76.0
# 0.1667

# %%
x=data['home.dest'].value_counts().idxmax()
print(x)
data['home.dest'].value_counts()
# Out:
# New York, NY
# New York, NY                                      45
# London                                            10
# Montreal, PQ                                       7
# Cornwall / Akron, OH                               7
# Paris, France                                      7
# Sweden Winnipeg, MN                                6
# Philadelphia, PA                                   6
# Wiltshire, England Niagara Falls, NY               6
# Winnipeg, MB                                       5
# Brooklyn, NY                                       5
# Belfast                                            5
# Guernsey / Elizabeth, NJ                           4
# Ruotsinphytaa, Finland New York, NY                4
# Ottawa, ON                                         4
# Chicago, IL                                        4
# San Francisco, CA                                  4
# Rotherfield, Sussex, England Essex Co, MA          4
# ...

# %%
print(data[(data['home.dest']==x)].ix[:,:])
# Out:
#      pclass  survived                                               name  \
# 19        1         1       Greenfield, Mrs. Leo David (Blanche Strouse)
# 24        1         1             Taussig, Mrs. Emil (Tillie Mandelbaum)
# 62        1         0                          Cumings, Mr. John Bradley
# 73        1         1                        Leader, Dr. Alice (Farnham)
# 76        1         0                           Guggenheim, Mr. Benjamin
# 84        1         0                     Holverson, Mr. Alexander Oskar
# 118       1         0                           Hoyt, Mr. William Fisher
# 136       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 157       1         1  Frauenthal, Mrs. Henry William (Clara Heinshei...
# 177       1         0        Rosenshine, Mr. George ("Mr George Thorne")
# 178       1         1                      Frauenthal, Dr. Henry William
# 219       1         0                           Carlsson, Mr. Frans Olof
# ...

# %%
max_fare=data['fare'].max()
print(max_fare)
# Out:
# 512.3292

# %%
data[(data['fare']==max_fare)]["name"].tolist()
# Out:
# ['Cardeza, Mrs. James Warburton Martinez (Charlotte Wardle Drake)',
#  'Cardeza, Mr. Thomas Drake Martinez',
#  'Lesurer, Mr. Gustave J',
#  'Ward, Miss. Anna']

# %%
min_fare=data['fare'].min()
print(min_fare)
# Out:
# 0.0

# %%
data[(data['fare']==min_fare)]["name"].tolist()
# Out:
# ['Campbell, Mr. William',
#  'Fry, Mr. Richard',
#  'Leonard, Mr. Lionel',
#  'Parr, Mr. William Henry Marsh',
#  'Reuchlin, Jonkheer. John George',
#  'Watson, Mr. Ennis Hastings',
#  'Tornquist, Mr. William Henry',
#  'Parkes, Mr. Francis "Frank"',
#  'Ismay, Mr. Joseph Bruce',
#  'Chisholm, Mr. Roderick Robert Crispin',
#  'Cunningham, Mr. Alfred Fleming']

# %%
data[(data['home.dest']==x)]
# Out:
#      pclass  survived                                               name  \
# 19        1         1       Greenfield, Mrs. Leo David (Blanche Strouse)
# 24        1         1             Taussig, Mrs. Emil (Tillie Mandelbaum)
# 62        1         0                          Cumings, Mr. John Bradley
# 73        1         1                        Leader, Dr. Alice (Farnham)
# 76        1         0                           Guggenheim, Mr. Benjamin
# 84        1         0                     Holverson, Mr. Alexander Oskar
# 118       1         0                           Hoyt, Mr. William Fisher
# 136       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 157       1         1  Frauenthal, Mrs. Henry William (Clara Heinshei...
# 177       1         0        Rosenshine, Mr. George ("Mr George Thorne")
# 178       1         1                      Frauenthal, Dr. Henry William
# 219       1         0                           Carlsson, Mr. Frans Olof
# ...

# %%
for i in range(len(data)):
    if pd.isnull(data.loc[i,'age']):
        data.loc[i,'age']=avg_age[data.loc[i,'sex']]
