# %%
import pandas as pd

# %%
data = pd.read_excel('/media/mohit/mohit1/githubfile/pysessions/dataset/killed_journalists.xls')

# %%
data.head()
# Out:
#                 Date                               Name   Sex Country Killed  \
# 0  February 25, 2017  Shifa Zikri Ibrahim (Shifa Gardi)  Male           Iraq
# 1  February 12, 2017                       Taimoor Khan  Male       Pakistan
# 2  February  3, 2017                 Abdul Hakim Shimul  Male     Bangladesh
# 3  December 15, 2016            Mohammad Nasir Mudasir   Male    Afghanistan
# 4  December 13, 2016                       Soe Moe Tun   Male        Myanmar
#
#           Organization  Nationality      Medium              Job  \
# 0             Rudaw TV        Iraqi  Television        Broadcast
# 1             Samaa TV    Pakistani  Television  Camera Operator
# 2             Samakal   Bangladeshi       Print   Print Reporter
# 3  Melli Paigham Radio       Afghan       Radio           Editor
# 4         Daily Eleven      Myanmar       Print   Print Reporter
#
#             Coverage Freelance Local/Foreign                 Source of Fire  \
# ...

# %%
for i in range(len(data)):
    #if (data.loc[i,'Tortured\n'])=="\n":
    data.loc[i,"Tortured\n"]=data.loc[i,'Tortured\n'].replace("\n","")
        
data
# Out:
#                           Date                               Name   Sex  \
# 0            February 25, 2017  Shifa Zikri Ibrahim (Shifa Gardi)  Male
# 1            February 12, 2017                       Taimoor Khan  Male
# 2            February  3, 2017                 Abdul Hakim Shimul  Male
# 3            December 15, 2016            Mohammad Nasir Mudasir   Male
# 4            December 13, 2016                       Soe Moe Tun   Male
# 5            November 18, 2016                     Awab al-Zubiry  Male
# 6            November 12, 2016                     Mohsen Khazaei  Male
# 7            November  6, 2016                 Mahad Ali Mohamed   Male
# 8            November  4, 2016                 Naimatullah Zaheer  Male
# 9             October 31, 2016                 Abdul Salam Kanaan  Male
# 10            October 22, 2016                          Ali Risan  Male
# 11            October 21, 2016                    Ahmet Haceroğlu  Male
# ...

# %%
for i in range(len(data)):
    #if (data.loc[i,'Tortured\n'])=="\n":
        data.loc[i,"Year"]=str(data.loc[i,'Date']).split()[-1]
    
data
# Out:
#                           Date                               Name   Sex  \
# 0            February 25, 2017  Shifa Zikri Ibrahim (Shifa Gardi)  Male
# 1            February 12, 2017                       Taimoor Khan  Male
# 2            February  3, 2017                 Abdul Hakim Shimul  Male
# 3            December 15, 2016            Mohammad Nasir Mudasir   Male
# 4            December 13, 2016                       Soe Moe Tun   Male
# 5            November 18, 2016                     Awab al-Zubiry  Male
# 6            November 12, 2016                     Mohsen Khazaei  Male
# 7            November  6, 2016                 Mahad Ali Mohamed   Male
# 8            November  4, 2016                 Naimatullah Zaheer  Male
# 9             October 31, 2016                 Abdul Salam Kanaan  Male
# 10            October 22, 2016                          Ali Risan  Male
# 11            October 21, 2016                    Ahmet Haceroğlu  Male
# ...

# %%
data.loc[1,'Date'].split()[-1]
# Out:
# '2017'

# %%
data
# Out:
#                           Date                               Name   Sex  \
# 0            February 25, 2017  Shifa Zikri Ibrahim (Shifa Gardi)  Male
# 1            February 12, 2017                       Taimoor Khan  Male
# 2            February  3, 2017                 Abdul Hakim Shimul  Male
# 3            December 15, 2016            Mohammad Nasir Mudasir   Male
# 4            December 13, 2016                       Soe Moe Tun   Male
# 5            November 18, 2016                     Awab al-Zubiry  Male
# 6            November 12, 2016                     Mohsen Khazaei  Male
# 7            November  6, 2016                 Mahad Ali Mohamed   Male
# 8            November  4, 2016                 Naimatullah Zaheer  Male
# 9             October 31, 2016                 Abdul Salam Kanaan  Male
# 10            October 22, 2016                          Ali Risan  Male
# 11            October 21, 2016                    Ahmet Haceroğlu  Male
# ...

# %%
for i in range(len(data)):
    if (data.loc[i,'Tortured\n'])=="":
        data.loc[i,"Tortured\n"]=data.loc[i,'Tortured\n'].replace("","unknown")
data
# Out:
#                           Date                               Name   Sex  \
# 0            February 25, 2017  Shifa Zikri Ibrahim (Shifa Gardi)  Male
# 1            February 12, 2017                       Taimoor Khan  Male
# 2            February  3, 2017                 Abdul Hakim Shimul  Male
# 3            December 15, 2016            Mohammad Nasir Mudasir   Male
# 4            December 13, 2016                       Soe Moe Tun   Male
# 5            November 18, 2016                     Awab al-Zubiry  Male
# 6            November 12, 2016                     Mohsen Khazaei  Male
# 7            November  6, 2016                 Mahad Ali Mohamed   Male
# 8            November  4, 2016                 Naimatullah Zaheer  Male
# 9             October 31, 2016                 Abdul Salam Kanaan  Male
# 10            October 22, 2016                          Ali Risan  Male
# 11            October 21, 2016                    Ahmet Haceroğlu  Male
# ...

# %%
data2=data["Tortured\n"].value_counts()

# %%
data2
# Out:
# No         1003
# unknown     709
# Yes          99
# Name: Tortured\n, dtype: int64

# %%
# %matplotlib inline
data2.plot(kind="bar")

# %%
list(data.groupby('Tortured\n'))
# Out:
# [('No',                     Date                          Name     Sex  \
#   3      December 15, 2016       Mohammad Nasir Mudasir     Male
#   15       August 14, 2016                  Mustafa Said    Male
#   16       August  8, 2016                 Shehzad Ahmed    Male
#   17       August  8, 2016                  Mehmood Khan    Male
#   21         July 24, 2016         João Miranda do Carmo    Male
#   23         July 20, 2016                Pavel Sheremet    Male
#   31         June 25, 2016                 Khaled Eissa     Male
#   33         June 19, 2016           Elidio Ramos Zárate    Male
#   36         June  5, 2016            Zabihullah Tamanna    Male
#   39          May 13, 2016                 Rajdev Ranjan    Male
#   40        April 12, 2016              Zaher al-Shurqat    Male
#   44     February 13, 2016                   Karun Misra    Male
#   45     February  5, 2016       El-Hadj Mohamed Diallo     Male
# ...

# %%
data4=data[(data['Country Killed']=='Nepal')]
data4
# Out:
#                      Date                      Name     Sex Country Killed  \
# 492      January 11, 2009                 Uma Singh  Female          Nepal
# 550      October  4, 2007             Birendra Shah    Male          Nepal
# 564   2007-07-07 00:00:00     Prakash Singh Thakuri    Male          Nepal
# 671       October 4, 2005          Maheshwar Pahari    Male          Nepal
# 737       August 11, 2004        Dekendra Raj Thapa    Male          Nepal
# 784    September  7, 2003          Gyanendra Khadka    Male          Nepal
# 817      January 30, 2003  Dhan Bahadur Rokka Magar    Male          Nepal
# 831         June  1, 2002           Nava Raj Sharma    Male          Nepal
# 1447       April  3, 2012              Yadav Poudel     NaN          Nepal
# 1503        July 22, 2010        Devi Prasad Dhital     NaN          Nepal
# 1517       March  1, 2010           Arun Singhaniya     NaN          Nepal
# ...

# %%
i=range(len(data4))
print(i)
data4.index=list(range(len(data4)))
for i in range(len(data4)):
    if pd.isnull(data4.loc[i,'Source of Fire']):
        data4.loc[i,'Source of Fire']="unknown"
# Out:
# range(0, 17)

# %%
data4
# Out:
#                    Date                      Name     Sex Country Killed  \
# 0      January 11, 2009                 Uma Singh  Female          Nepal
# 1      October  4, 2007             Birendra Shah    Male          Nepal
# 2   2007-07-07 00:00:00     Prakash Singh Thakuri    Male          Nepal
# 3       October 4, 2005          Maheshwar Pahari    Male          Nepal
# 4       August 11, 2004        Dekendra Raj Thapa    Male          Nepal
# 5    September  7, 2003          Gyanendra Khadka    Male          Nepal
# 6      January 30, 2003  Dhan Bahadur Rokka Magar    Male          Nepal
# 7         June  1, 2002           Nava Raj Sharma    Male          Nepal
# 8        April  3, 2012              Yadav Poudel     NaN          Nepal
# 9         July 22, 2010        Devi Prasad Dhital     NaN          Nepal
# 10       March  1, 2010           Arun Singhaniya     NaN          Nepal
# 11    February  8, 2010                Jamim Shah     NaN          Nepal
# ...

# %%
data4["Source of Fire"].value_counts().plot(kind="bar")

# %%
max_murdered=data4['Year'].value_counts().idxmax()
print(max_murdered)
# Out:
# 2010

# %%
data4[(data4['Year']==max_murdered)]
# Out:
#                  Date                Name  Sex Country Killed  \
# 9       July 22, 2010  Devi Prasad Dhital  NaN          Nepal
# 10     March  1, 2010     Arun Singhaniya  NaN          Nepal
# 11  February  8, 2010          Jamim Shah  NaN          Nepal
#
#                             Organization Nationality Medium  Job Coverage  \
# 9                      Radio Tulsipur FM       Nepal    NaN  NaN      NaN
# 10                           Today Group         NaN    NaN  NaN      NaN
# 11  Channel Nepal and Space Time Network       Nepal    NaN  NaN      NaN
#
#    Freelance Local/Foreign Source of Fire Type of Death Impunity (for Murder)  \
# 9        NaN           NaN        unknown           NaN                   NaN
# 10       NaN           NaN        unknown           NaN                   NaN
# 11       NaN           NaN        unknown           NaN                   NaN
#
#    Taken Captive Threatened Tortured\n  Year
# 9            NaN        NaN    unknown  2010
# ...

# %%
dat = data[data['Year']=='2000']
h=dat['Country Killed'].value_counts()
max_=dat['Country Killed'].value_counts().max()


print(h.index)
for i in h.index:
    if h[i]==max_:
        print(i)
# Out:
# Index(['Russia', 'Colombia', 'India', 'Sierra Leone', 'Mexico', 'Haiti',
#        'Philippines', 'Ukraine', 'Bangladesh', 'Nepal',
#        'Israel and the Occupied Palestinian Territory', 'Mozambique',
#        'Guatemala', 'Brazil', 'Kenya', 'Uruguay', 'Yugoslavia', 'USA',
#        'Georgia', 'Pakistan', 'Sri Lanka', 'Spain', 'Somalia'],
#       dtype='object')
# Russia
# Colombia
