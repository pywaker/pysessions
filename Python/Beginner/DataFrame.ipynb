# %%
import pandas as pd

data1 = pd.read_csv(open(r'/media/mohit/mohit1/githubfile/pysessions/dataset/day.csv','r'))

# %%
data1.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
data1.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ...

# %%
# %matplotlib inline
c=data1.groupby('mnth')["cnt"].mean().plot(kind='bar',width=0.5)
c.set_xticklabels(['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'],rotation=30)

# %%
c=data1.groupby('weekday')["casual","registered"].mean().plot(kind='bar',width=0.5)
#d=data1.groupby('weekday')["registered"].mean().plot(kind='bar',width=0.5)

# %%
data1[data1['workingday']==0].groupby("season")["cnt"].mean().plot(kind='bar',width=0.5)

# %%
data1[(data1['season']==1)&(data1['workingday']==1)].ix[:,-1].mean()
# Out:
# 2780.5416666666665

# %%
v=data1['cnt'].idxmax()
data1.iloc[v,1]
# Out:
# '2012-09-15'

# %%
data1.iloc[data1['cnt'].idxmax()]['dteday']
# Out:
# '2012-09-15'
