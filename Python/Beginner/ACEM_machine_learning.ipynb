# %%
import pandas as pd

# %%
data = pd.read_excel('/media/mohit/mohit1/githubfile/pysessions/dataset/winequality-red1.xls',sep=";")a

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
data.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import matplotlib.pylab as plt
plt.scatter(data['alcohol'],data['quality'])
plt.show()

# %% [markdown]
# ## Evaluating the performance of model:
# ## We will split the dataset into train data and test data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
x = data[list(data.columns)[:-1]]
y = data['quality']
x_train,x_test,y_train,y_test=train_test_split(x,y)
regressor = LinearRegression()
regressor.fit(x_train,y_train)
prediction  = regressor.predict(x_test)
print(prediction)
regressor.score(x_test,y_test)
x_test.count()
# Out:
# [ 5.36078422  6.37102809  6.19511966  6.79783029  5.14898709  5.3051066
#   5.56718212  4.67050069  5.87406036  6.00401878  6.17770307  5.17880237
#   5.79892104  5.04878696  5.40928786  5.21409103  5.59692602  5.87926761
#   6.04733998  6.15072289  5.36807123  5.57194743  4.85997078  4.97271862
#   5.869467    6.50433945  5.23928606  6.08529594  5.76478237  5.99969468
#   6.43074999  6.26295163  5.67731419  5.73871598  4.99847839  7.62716933
#   6.18611195  5.24521774  4.80723258  6.00496137  5.70658278  5.25617004
#   4.20430798  5.40627941  5.04628961  5.28635127  6.01410377  5.91574631
#   6.62628461  5.27053729  6.14156476  5.98056687  5.7564537   6.27080981
#   6.05138924  5.0362875   6.03684315  5.02226478  6.71874958  5.78865344
#   5.8948698   5.4890485   6.16616364  5.58389553  5.37704627  5.45241664
#   6.02252302  5.77200085  6.15127025  5.04079291  5.33394926  5.00745295
#   6.45147846  5.54724013  5.94161933  5.86879585  4.91432347  6.03467387
# ...

# %%
from sklearn.cross_validation import cross_val_score
scores = cross_val_score(x,y,cv=5)
scores.mean(),scores
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-4836ceea94b2> in <module>()
#       1 from sklearn.cross_validation import cross_val_score
# ----> 2 scores = cross_val_score(x,y,cv=5)
#       3 scores.mean(),scores
#
# /home/mohit/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1561
#    1562     cv = check_cv(cv, X, y, classifier=is_classifier(estimator))
# -> 1563     scorer = check_scoring(estimator, scoring=scoring)
#    1564     # We clone the estimator to make sure that all the folds are
#    1565     # independent, and that it is pickle-able.
#
# /home/mohit/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py in check_scoring(estimator, scoring, allow_none)
#     248     if not hasattr(estimator, 'fit'):
# ...

# %%
from sklearn.feature_extraction import DictVectorizer
onehot_encoder = DictVectorizer()
instances = [{'city': 'New York'},{'city':'San Francisco'},{'city':'Chapel hill'}]
print(onehot_encoder.fit_transform(instances).toarray())
# Out:
# [[ 0.  1.  0.]
#  [ 0.  0.  1.]
#  [ 1.  0.  0.]]

# %%
instances.values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-30e6182cf3f4> in <module>()
# ----> 1 instances.values()
#
# AttributeError: 'list' object has no attribute 'values'
